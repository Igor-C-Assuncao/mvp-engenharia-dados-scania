-- %%
SELECT
COUNT(*) AS qtd_chaves_duplicadas
FROM (
SELECT vehicle_id, time_step, dataset_split, COUNT(*) AS c
FROM gold_fato_snapshot
GROUP BY vehicle_id, time_step, dataset_split
HAVING COUNT(*) > 1
) d;
