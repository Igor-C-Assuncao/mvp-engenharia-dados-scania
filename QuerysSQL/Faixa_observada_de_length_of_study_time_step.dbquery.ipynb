-- %%
SELECT
MIN(length_of_study_time_step) AS min_length,
MAX(length_of_study_time_step) AS max_length,
AVG(length_of_study_time_step) AS avg_length
FROM gold_fato_tempo_ate_evento
WHERE length_of_study_time_step IS NOT NULL;
