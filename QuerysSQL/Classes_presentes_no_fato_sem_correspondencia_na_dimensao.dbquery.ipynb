-- %%
SELECT
COUNT(*) AS qtd_sem_dim_classe
FROM gold_fato_snapshot f
LEFT JOIN gold_dim_classe_proximidade c
ON f.class_label = c.class_label
WHERE f.class_label IS NOT NULL
AND c.class_label IS NULL;
